# %%
import pandas as pd
# import numpy as np
from numpy import log as ln
df = pd.DataFrame(columns = ['version', 'dry1', 'glow1', 'reserve', 'dry2', 'glow2', 'payload', 'isp1', 'isp2', 'thrust1', 'thrust2'])
df = df.append(pd.DataFrame([['NG_120_45_ton_cargo', 110.0, 1100.0, 50, 12.0, 120, 45.0, 320.0, 440.0, 1900, 120 ]], columns=df.columns)
).append(pd.DataFrame([['NG_120_30_ton_cargo', 110, 1100, 50, 12, 120, 30, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_120_13_ton_cargo', 110, 1100, 50, 12, 120, 13, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_120_7_ton_cargo', 110, 1100, 50, 12, 120, 7, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_120_20_ton_cargo', 110, 1100, 100, 12, 120, 20, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_120_13_ton_cargo', 110, 1100, 100, 12, 120, 13, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_120_7_ton_cargo', 110, 1100, 100, 12, 120, 7, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_200_45_ton_cargo', 110, 1100, 50, 16, 200, 45, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_200_20_ton_cargo', 110, 1100, 50, 16, 200, 20, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_200_13_ton_cargo', 110, 1100, 50, 16, 200, 13, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_200_7_ton_cargo', 110, 1100, 50, 16, 200, 7, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_200_45_ton_cargo', 110, 1100, 100, 16, 200, 45, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_200_40_ton_cargo', 110, 1100, 100, 16, 200, 40, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_200_13_ton_cargo', 110, 1100, 100, 16, 200, 13, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['NG_200_7_ton_cargo', 110, 1100, 100, 16, 200, 7, 320, 440, 1900, 120]], columns=df.columns)
).append(pd.DataFrame([['Falcon_9_block5_GTO_reuse', 27.2, 455, 45, 4.5, 125, 5.5, 300, 348, 810, 95]], columns=df.columns)
).append(pd.DataFrame([['Falcon_9_block5_fairing_limit', 27.2, 455, 45, 4.5, 125, 10.886, 300, 348, 810, 95]], columns=df.columns)
).append(pd.DataFrame([['Falcon_9_block5_fuller_splash', 27.2, 455, 0, 4.5, 125, 22.8, 300, 348, 810, 95]], columns=df.columns))

df['fuel1'] = (df.glow1 - df.dry1 - df.reserve)
df['fuel2'] = (df.glow2 - df.dry2 - df.payload)
df['seperation'] = (df.dry1 + df.reserve + df.glow2)
df['burnout'] = (df.dry2+df.payload).astype(float)
df['delta1'] = 9.81 * df.isp1 * ln( (df.glow1+df.glow2).astype(float) / (df.seperation).astype(float))
# velocity * ln (m0/m1)
df['delta2'] = 9.81 * df.isp2 * ln((df.glow2.astype(float) / df.burnout.astype(float)))
df['delta_total'] = df.delta1+df.delta2
# df['burn1'] = df.fuel1/(df.thrust1/df.isp1/9.8)
# df['burn2'] = df.fuel2/(df.thrust2/df.isp2/9.8)
df.head(20)
# Out:
#                          version   dry1   glow1 reserve  dry2 glow2  payload  \
# 0            NG_120_45_ton_cargo  110.0  1100.0      50  12.0   120   45.000
# 0            NG_120_30_ton_cargo  110.0  1100.0      50  12.0   120   30.000
# 0            NG_120_13_ton_cargo  110.0  1100.0      50  12.0   120   13.000
# 0             NG_120_7_ton_cargo  110.0  1100.0      50  12.0   120    7.000
# 0            NG_120_20_ton_cargo  110.0  1100.0     100  12.0   120   20.000
# 0            NG_120_13_ton_cargo  110.0  1100.0     100  12.0   120   13.000
# 0             NG_120_7_ton_cargo  110.0  1100.0     100  12.0   120    7.000
# 0            NG_200_45_ton_cargo  110.0  1100.0      50  16.0   200   45.000
# 0            NG_200_20_ton_cargo  110.0  1100.0      50  16.0   200   20.000
# 0            NG_200_13_ton_cargo  110.0  1100.0      50  16.0   200   13.000
# 0             NG_200_7_ton_cargo  110.0  1100.0      50  16.0   200    7.000
# ...
